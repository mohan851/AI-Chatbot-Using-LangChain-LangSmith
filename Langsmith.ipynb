# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_PROJECT"] = "krishna-chatbot"
os.environ["LANGSMITH_ENDPOINT"]= "https://api.smith.langchain.com"

# %%
from langchain_groq import ChatGroq
from langchain_core.output_parsers import StrOutputParser

groq_api = os.getenv("GROQ_API_KEY")
llm = ChatGroq(api_key=groq_api,
               model="llama-3.3-70b-versatile",
               temperature=1,
               max_tokens=500)

parser = StrOutputParser()
chain = llm | parser

while True:
    question  = input("question : ")
    if question in ["bye" , "exit"]:
        response = chain.invoke(question)
        print(response)
        break
    else:
        response = chain.invoke(question)
        print(response)
# Out:
# question :  abut ronaldo
# Cristiano Ronaldo is a Portuguese professional soccer player widely regarded as one of the greatest players of all time. Here are some key facts about him:
#
# **Early Life and Career**
#
# * Born on February 5, 1985, in Funchal, Madeira, Portugal
# * Started playing soccer at a young age, joining local club Andorinha at 8 years old
# * Moved to Nacional da Madeira at 10 and then to Sporting CP at 12
#
# **Professional Career**
#
# * Made his professional debut for Sporting CP in 2002
# * Signed with Manchester United in 2003, where he won three Premier League titles and the Champions League
# * Joined Real Madrid in 2009, winning two La Liga titles and four Champions League titles
# * Signed with Juventus in 2018, where he currently plays
#
# **Achievements and Accolades**
#
# * Five-time Ballon d'Or winner (2008, 2013, 2014, 2016, and 2017)
# * Four-time UEFA Champions League winner (2008, 2014, 2016, and 2017)
# * Five-time UEFA Best Player in Europe (2014, 2016, 2017, 2018, and 2020)
# * All-time leading scorer in the UEFA Champions League
# * Portugal's all-time leading scorer
#
# **International Career**
#
# * Made his debut for Portugal in 2003
# * Led Portugal to victory in the 2016 European Championship
# * Represented Portugal in four World Cups (2006, 2010, 2014, and 2018)
#
# **Personal Life**
#
# * Known for his philanthropic efforts, particularly in his native Madeira
# * Has four children, including a son named Cristiano Jr.
# * Engaged to Georgina Rodríguez, a Spanish model
#
# **Playing Style and Legacy**
#
# * Renowned for his speed, skill, and goal-scoring ability
# * A prolific goal-scorer, with over 750 goals in his career
# * Considered one of the most dominant players of his generation, known for his work ethic and dedication to training
#
# Overall, Cristiano Ronaldo is a soccer legend, with a career marked by numerous achievements, awards, and records. He continues to inspire fans around the world with his incredible talent and dedication to the sport.
# question :  who is ronaldo
# Cristiano Ronaldo dos Santos Aveiro, commonly known as Cristiano Ronaldo, is a Portuguese professional footballer who is widely regarded as one of the greatest players of all time. He was born on February 5, 1985, in Funchal, Madeira, Portugal.
#
# Ronaldo began his youth career at CF Andorinha, and later moved to Nacional da Madeira and then to Sporting CP. He was signed by Manchester United in 2003, where he spent six successful seasons, winning three Premier League titles, the Champions League, and the FIFA Club World Cup.
#
# In 2009, Ronaldo joined Real Madrid, where he spent nine seasons, winning two La Liga titles, four Champions League titles, and numerous other trophies. He then moved to Juventus in 2018, where he played for three seasons before joining Manchester United again in 2021.
#
# Throughout his career, Ronaldo has won numerous individual awards, including:
#
# * Five Ballon d'Or awards (2008, 2013, 2014, 2016, and 2017)
# * Four European Golden Shoes (2008, 2011, 2014, and 2015)
# * UEFA Best Player in Europe award (2014 and 2016)
# * FIFA World Player of the Year (2008)
#
# Ronaldo is known for his exceptional speed, skill, and goal-scoring ability, as well as his dedication and work ethic. He is also a prolific philanthropist, supporting various charitable causes, including healthcare, education, and disaster relief.
#
# Some of his notable records and achievements include:
#
# * All-time leading scorer in the Champions League (140 goals)
# * All-time leading scorer in the European Championship (29 goals)
# * Most hat-tricks in the Champions League (8)
# * Fastest player to reach 100 goals in the Champions League (134 games)
#
# Ronaldo has also been named as one of the highest-paid athletes in the world by Forbes magazine, and has been featured on the cover of numerous magazines, including Time, Sports Illustrated, and Vogue.
#
# Overall, Cristiano Ronaldo is a highly decorated and talented footballer who has made a significant impact on the sport, and is widely regarded as one of the greatest players of all time.
